# %%
import pandas as pd

df = pd.read_csv(r"/home/ayoub/Desktop/avito_machine_learning_pipeline/data/obt_data.csv")

df.shape
# Out:
# (10356, 12)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10356 entries, 0 to 10355
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   annonce_id      10356 non-null  int64
#  1   title           10356 non-null  str
#  2   price           10356 non-null  int64
#  3   location        10356 non-null  str
#  4   surface         10356 non-null  int64
#  5   rooms           10356 non-null  int64
#  6   baths           10356 non-null  int64
#  7   link            10356 non-null  str
#  8   city            10356 non-null  str
#  9   neighborhood    10356 non-null  str
#  10  price_meter     10356 non-null  int64
#  11  price_category  10356 non-null  str
# dtypes: int64(6), str(6)
# memory usage: 971.0 KB

# %%
df.isna().sum()
# Out:
# annonce_id        0
# title             0
# price             0
# location          0
# surface           0
# rooms             0
# baths             0
# link              0
# city              0
# neighborhood      0
# price_meter       0
# price_category    0
# dtype: int64
